# %% [markdown]
# # Ejercicios Python

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Contar cuántos valores hay en una lista de enteros. Contar solo hasta el número 0.

# %%
nums = [6,8,5,2,0,6,5]
contador = 0
#Respuesta:
#Debe dar 5
for variable in nums:
  contador = contador +1
  print(contador)
  if variable == 0:
    break
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Sumar los valores que hay en una lista de enteros. Sumar solo hasta el número 0.

# %%
nums = [6, 8, 5, 2, 0, 6, 5]
suma = sum(nums)  # Utiliza la función sum para calcular la suma de los valores en la lista

print(suma)

###################################################################################
nums = [6,8,5,2,0,6,5]
suma = 0
#Respuesta:
#Debe dar 21
nums = [6, 8, 5, 2, 0, 6, 5]
suma = 0

for valor in nums:
    if valor == 0:
        break  # Detenemos la suma cuando encontramos un 0
    suma += valor

print( suma)
# Out:
# 32
# 21

# %%
nums = [6, 8, 5, 2, 0, 6, 5]
suma = sum(nums)  # Utiliza la función sum para calcular la suma de los valores en la lista

print(suma)
# Out:
# 32

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Calcular el valor medio de los valores que hay en una lista de enteros. Calcular solo hasta el número 0.

# %%
suma / contador
# Out:
# 4.2

# %%
nums = [6,8,5,2,0,6,5]
suma = 0
contador = 0
#Respuesta:
#Debe dar 4.2
# Out:
# 32

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Elimina las "a" del siguiente texto:

# %%
texto = "Las variables son almacenes de datos que persisten en memoria. Cuando accedemos a una variable en realidad estamos accediendo a un puntero en memoria que almacena el valor que nos interesa. "
#Respuesta

# %% [markdown]
# ## Ejercicio 5 (Opcional)

# %% [markdown]
# Crear una lista a partir de una secuencia de valores de entrada terminada en *.
# Una vez creada, modificarla elevando al cuadrado todos los pares y al cubo todos los impares, y mostrarla.

# %%
lista = [3,56,6,7,"*",2,78]
#Respuesta:
#Debe dar [27, 3136, 36, 343]
# Out:
# [27, 3136, 36, 343]
